# %% [markdown]
# ## 課題①

# %%
import numpy as np
from sklearn.datasets import load_boston
boston = load_boston()
import pandas as pd
X=pd.DataFrame(boston.data[:100,:], columns=boston.feature_names)
y=boston.target[:100] #データを100個に限定
x=X['LSTAT'].values # 特徴量LSTATを使用

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.scatter(x,y)

from sklearn.linear_model import LinearRegression #線形回帰の各関数のインスタンスを生成
lin_1d=LinearRegression()
lin_1d.fit(x[:,None],y)

from sklearn.preprocessing import PolynomialFeatures
degree_2 = PolynomialFeatures(degree=2)
x_2=degree_2.fit_transform(x[:,None])
degree_3 = PolynomialFeatures(degree=3)
x_3=degree_3.fit_transform(x[:,None])
degree_4 = PolynomialFeatures(degree=4)
x_4=degree_4.fit_transform(x[:,None])

lin_2d = LinearRegression()
lin_2d.fit(x_2,y)
lin_3d = LinearRegression()
lin_3d.fit(x_3,y)
lin_4d = LinearRegression()
lin_4d.fit(x_4,y)

n=np.linspace(np.min(x),np.max(x),1000)
y_4d_fit = lin_4d.predict(degree_4.fit_transform(n[:,np.newaxis]))
y_3d_fit = lin_3d.predict(degree_3.fit_transform(n[:,np.newaxis]))
y_2d_fit = lin_2d.predict(degree_2.fit_transform(n[:,np.newaxis]))
y_1d_fit=lin_1d.predict(n[:,np.newaxis])

plt.title("Boston House Price")
plt.scatter(x,y,label='data')
plt.plot(n,y_4d_fit,'b',label='4d_lin')
plt.plot(n,y_3d_fit,'y',label='3d_lin')
plt.plot(n,y_2d_fit,'g',label='2d_lin')
plt.plot(n,y_1d_fit,'r',label='1d_lin')
plt.ylim(10,40)#グラフを見やすくするためにｙ軸のプロット範囲を絞ります。
plt.xlabel("LSTAT")
plt.ylabel("price")
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# #### 3次関数の２乗和誤差を計算

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y,lin_3d.predict(x_3))
# Out:
# 10.055225709746376

# %% [markdown]
# #### 4次関数の２乗和誤差を計算

# %%
mean_squared_error(y,lin_4d.predict(x_4))
# Out:
# 9.617390715416672

# %% [markdown]
# ### 以上から２乗和誤差の最も小さいのは４次関数である。

# %% [markdown]
# ## 課題②

# %%
import numpy as np
from sklearn.datasets import load_boston
boston = load_boston()
import pandas as pd
X=pd.DataFrame(boston.data[:100,:], columns=boston.feature_names)
y=boston.target[:100] #データを100個に限定
x=X['AGE'].values # 特徴量AGEを使用

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.scatter(x,y)

from sklearn.linear_model import LinearRegression #線形回帰の各関数のインスタンスを生成
lin_1d=LinearRegression()
lin_1d.fit(x[:,None],y)

from sklearn.preprocessing import PolynomialFeatures
degree_2 = PolynomialFeatures(degree=2)
x_2=degree_2.fit_transform(x[:,None])
degree_3 = PolynomialFeatures(degree=3)
x_3=degree_3.fit_transform(x[:,None])
degree_4 = PolynomialFeatures(degree=4)
x_4=degree_4.fit_transform(x[:,None])

lin_2d = LinearRegression()
lin_2d.fit(x_2,y)
lin_3d = LinearRegression()
lin_3d.fit(x_3,y)
lin_4d = LinearRegression()
lin_4d.fit(x_4,y)

n=np.linspace(np.min(x),np.max(x),1000)
y_4d_fit = lin_4d.predict(degree_4.fit_transform(n[:,np.newaxis]))
y_3d_fit = lin_3d.predict(degree_3.fit_transform(n[:,np.newaxis]))
y_2d_fit = lin_2d.predict(degree_2.fit_transform(n[:,np.newaxis]))
y_1d_fit=lin_1d.predict(n[:,np.newaxis])

plt.title("Boston House Price")
plt.scatter(x,y,label='data')
plt.plot(n,y_4d_fit,'b',label='4d_lin')
plt.plot(n,y_3d_fit,'y',label='3d_lin')
plt.plot(n,y_2d_fit,'g',label='2d_lin')
plt.plot(n,y_1d_fit,'r',label='1d_lin')
plt.ylim(10,40)#グラフを見やすくするためにｙ軸のプロット範囲を絞ります。
plt.xlabel("LSTAT")
plt.ylabel("price")
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# #### 以下順に各１〜４次関数の２条和誤差を計算していく。

# %%
mean_squared_error(y,lin_1d.predict(x[:,None]))
# Out:
# 26.754508704139507

# %%
mean_squared_error(y,lin_2d.predict(x_2))
# Out:
# 24.397088136515951

# %%
mean_squared_error(y,lin_3d.predict(x_3))
# Out:
# 23.978242199677442

# %%
mean_squared_error(y,lin_4d.predict(x_4))
# Out:
# 23.95681697681929

# %% [markdown]
# ### 以上から２乗和誤差の最も小さいのは４次関数である。
